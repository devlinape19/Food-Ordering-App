# %%
food_list=[]
food_menu={}
food_id=len(food_menu)
food_history={}
user_data={}
user_id=len(user_data)
total_amount=0
def EXIT():
  print('\n\n\n\t\t\tTHANK YOU FOR VISITING.')
def HOME():
  reply=input("WELCOME TO RESTAURANT APPLICATION.\n\n\n\nTO LOGIN AS AN ADMIN ENTER '1'. \nTO LOGIN AS A GUEST ENTER '2'. \nTO EXIT ENTER '3'.\n")
  while reply not in ['1','2','3']:
    reply=input("INVALID INPUT PLEASE CHOOSE FROM THE FOLLOWING: \nTO LOGIN AS AN ADMIN ENTER '1'. \nTO LOGIN AS A GUEST ENTER '2'. \nTO EXIT ENTER '3'.\n")
  if reply=='1':
    ADMIN()
  elif reply=='2':
    USER()
  else:
    EXIT()
def USER():
  reply=input("WELCOME GUEST! \nTO REGISTER ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while reply not in ['1','2']:
    reply=input("INVALID INPUT!! PLEASE CHOOSE FROM THE FOLLOWING :  \nTO REGISTER ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if reply=='1':
    REGISTER()
  else:
    EXIT()
def REGISTER():
  name=input('PLEASE ENTER YOUR FULL NAME FOR REGISTRATION :').upper()
  phone=input('PLEASE ENTER YOUR PHONE NUMBER :')
  email=input('PLEASE ENTER YOUR EMAIL ID :').lower()
  address=input("PLEASE ENTER YOUR DELIVERY ADDRESS :")
  password=input("PLEASE ENTER A STRONG PASSWORD :")
  if user_id==0:
    user_data[user_id+1]=[name,phone,email,address,password]
  else:
    for ele in user_data.values():
      if email not in ele :
        user_data[user_id+1]=[name,phone,email,address,password]

      else:
        reply=input("USER ALREADY HAS AN ACCOUNT. /nTO LOGIN ENTER '1'.\nTO EXIT ENTER '2'\n")
        while reply not in ['1','2']:
          reply=input("INVALID INPUT! PLEASE CHOOSE FROM THE FOLLOWING: \nTO LOGIN ENTER '1'. \nTO EXIT ENTER '2'.\n")
        if reply=='1':
          USER_LOGIN()
        else:
          EXIT()
  re=input("ACCOUNT CREATED SUCCESFULLY. \nTO LOGIN ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while re not in ['1','2']:
    re=input("INVALID INPUT! PLEASE CHOOSE FROM THE FOLLOWING: \nTO LOGIN ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if re=='1':
    USER_LOGIN()
  else:
    EXIT()
      

def USER_LOGIN():
  user_name=input('PLEASE ENTER YOUR EMAIL ID :')
  password=input('PLEASE ENTER YOUR PASSWORD :')
  for ele in user_data.values():
    if (user_name and password) in ele:
      reply=input("LOGIN SUCCESSFUL. \nTO PLACE AN ORDER ENTER'1'. \nTO VIEW YOUR ORDER HISTORY ENTER '2'. \nTO UPDATE YOUR PROFILE ENTER '3'\n")
      while reply not in ['1','2','3','4']:
          reply=input("INVALID INPUT! PLEASE CHOOSE FROM THE FOLLOWING: \nTO PLACE AN ORDER ENTER'1'. \nTO VIEW YOUR ORDER HISTORY ENTER '2'. \nTO UPDATE YOUR PROFILE ENTER '3'. \nTO EXIT ENTER '4'.\n")
      if reply=='1':
        PLACE_ORDER()
      elif reply=='2':
        ORDER_HISTORY()
      elif reply=='3':
        UPDATE_PROFILE()
      else:
        EXIT()
    else:
      reply=input("INVALID USER OR PASSWORD! \nTO REGISTER PLEASE INPUT '1'. \nTO EXIT PLEASE INPUT '2'.\n")
      while reply not in ['1','2']:
        reply=input("INVALID INPUT! PLEASE CHOOSE FROM THE FOLLOWING: \nTO REGISTER PLEASE INPUT '1'. \nTO EXIT PLEASE INPUT '2'.\n")
      if reply=='1':
        REGISTER()
      else:
        EXIT()
def PLACE_ORDER():
  user_food_id=input("PLEASE SELECT FROM THE FOLLOWING SEPARATED BY ' , '  :   \n1. Tandoori Chicken (4 pieces) [INR 240]; \n2. Vegan Burger (1 Piece) [INR 320]; \n3. Truffle Cake (500gm) [INR 900]  :").split(',')
  user_food_list=[]
  global total_amount
  for ele in user_food_id:
    if  ele=='1' and str(user_food_id.count(ele))+'x Tandoori Chicken (4 pieces) [INR 240]' not in user_food_list :
      user_food_list.append(str(user_food_id.count(ele))+'x Tandoori Chicken (4 pieces) [INR 240]')
    elif ele=='2' and str(user_food_id.count(ele))+'x Vegan Burger (1 Piece) [INR 320]' not in user_food_list:
      user_food_list.append(str(user_food_id.count(ele))+'x Vegan Burger (1 Piece) [INR 320]')
    elif ele=='3' and str(user_food_id.count(ele))+"x Truffle Cake (500gm) [INR 900]" not in user_food_list :
      user_food_list.append(str(user_food_id.count(ele))+"x Truffle Cake (500gm) [INR 900]")
  food_history[user_id]=user_food_list
  for ele in user_food_id:
    if ele not in ['1','2','3']:
      user_food_id=input("INVALID INPUT !!! PLEASE SELECT FROM THE FOLLOWING SEPARATED BY ' , '  :   \n1. Tandoori Chicken (4 pieces) [INR 240]; \n2. Vegan Burger (1 Piece) [INR 320]; \n3. Truffle Cake (500gm) [INR 900]  :").split(',')
      break
  print('THE ORDERED ITEMS ARE : {} '.format(user_food_list))
  reply=input("TO PLACE THE ORDER ENTER '1'. \nTO CHANGE THE ORDER ENTER '2', \nTO EXIT ENTER '3'.\n ")
  while reply not in ['1','2','3']:
    reply=input("INVALID INPUT! PLASE CHOOSE FROM THE FOLLOWING : \nTO PLACE THE ORDER ENTER '1'. \nTO CHANGE THE ORDER ENTER '2', \nTO EXIT ENTER '3'.\n ")
  if reply=='2':
    user_food_id.clear()
    user_food_id=input("PLEASE SELECT FROM THE FOLLOWING SEPARATED BY ' , '  :   \n1. Tandoori Chicken (4 pieces) [INR 240]; \n2. Vegan Burger (1 Piece) [INR 320]; \n3. Truffle Cake (500gm) [INR 900]  :").split(',')
    total_amount+=(user_food_id.count('1')*240)+(user_food_id.count('2')*320)+(user_food_id.count('3')*900)
    print('THE ORDERED ITEMS ARE : {} AND THE TOTAL; PAYABLE AMOUNT IS : INR.{}'.format(user_food_list,total_amount))
    EXIT()
  elif reply=='1':
    total_amount+=(user_food_id.count('1')*240)+(user_food_id.count('2')*320)+(user_food_id.count('3')*900)
    print('THE ORDERED ITEMS ARE : {} AND THE TOTAL PAYABLE AMOUNT IS : INR.{}'.format(user_food_list,total_amount))
    EXIT()
  else:
    EXIT()
  reply=input("THANK YOU FOR ORDERNING FROM US! \nTO RETURN BACK TO THE LOGIN PAGE ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while reply not in ['1','2']:
    reply=input("INVALID INPUT! PLEASE CHOOSE FROM THE FOLLOWING: \nTO RETURN BACK TO THE LOGIN PAGE ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if reply=='1':
    USER_LOGIN()
  else:
    EXIT()
def ORDER_HISTORY():
  if len(food_history)==0:
    print('NO ORDER HISTORY AVAILABLE')
  else:
    print(food_history[user_id])
  reply=input("TO RETURN BACK ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while reply not in ['1','2']:
    reply=input("INVALID INPUT!! PLEASE CHOOSE FOROM THE FOLLOWING:  \nTO RETURN BACK ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if reply=='1':
    USER_LOGIN()
  else:
    EXIT()
def UPDATE_PROFILE():
  reply=int(input('PLEASE SELECT ANY CODE TO UPDATE YOUR PROFILE: \n1. NAME \n2. PHONE NUMBER \n3. EMAIL ID \n4. DELIVERY ADDRESS \n5. PASSWORD\n'))
  while reply not in range(1,6):
    reply=int(input('INVALID CODE!! \nPLEASE TRY AGAIN. \nPLEASE SELECT ANY CODE TO UPDATE YOUR PROFILE: \n1. NAME \n2. PHONE NUMBER \n3. EMAIL ID \n4. DELIVERY ADDRESS \n5. PASSWORD\n'))
  user_data[1][reply-1]=input('PLEASE ENTER DETAIL TO UPDATE\n')
  reply=int(input("PROFILE UPDATED.\nTO SAVE THE DATA ENTER '0'. \nTO RETURN BACK ENTER '1'. \nTO EXIT ENTER '2'\n"))
  if reply==0:
    print('UPDATE SAVED SUCESSFULY\n.')
    print(user_data[1])
  elif reply==1:
    print('THE UPDATE WAS NOT SAVED\n')
    print(user_data[1])
  elif reply==2:
    EXIT()
def ADMIN():
  reply=input("\nWELCOME ADMIN! \n\n\nTO LOGIN ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while reply not in ['1','2']:
    reply=input("INVALID INPUT!! PLEASE CHOOSE FROM THE FOLLOWING :  \nTO LOGIN ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if reply=='1':
    ADMIN_LOGIN()
  else:
    EXIT()
def ADMIN_LOGIN():
  admin_id='admin@restaurant'
  admin_password='edyoda'
  answer='DS261121'
  reply1=input("PLEASE ENTER YOUR ADMIN ID.\nHINT : admin@restaurant \n")
  reply2=input("PLEASE ENTER YOUR PASSWORD. \nHINT : edyoda \n")
  if (reply1!=admin_id) or (reply2!=admin_password):
    reply=input('INVALID ID OR PASSWORD. \nWHAT IS YOUR BATCH? \nHINT : DS261121\n')
    if reply!=answer:
      HOME()
    else:
      print("WELCOME ADMIN! \n\nLOGIN SUCCESSFUL.\n")
      reply=input("\nTO VIEW THE MENU ENTER '1'. \nTO UPDATE THE MENU ENTER '2'. \nTO EXIT ENTER '3'.\n")
      while reply not in ['1','2','3']:
        reply=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING: \nTO VIEW THE MENU ENTER '1'. \nTO UPDATE THE MENU ENTER '2'. \nTO LOGOUT ENTER '3'.\n")
      if reply=='1':
        VIEW_MENU()
      elif reply=='2':
        UPDATE_MENU()
      else:
        HOME()

  else:
    print("WELCOME ADMIN! \n\nLOGIN SUCCESSFUL.\n")
    reply=input("\nTO VIEW THE MENU ENTER '1'. \nTO UPDATE THE MENU ENTER '2'. \nTO EXIT ENTER '3'.\n")
    while reply not in ['1','2','3']:
      reply=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING: \nTO VIEW THE MENU ENTER '1'. \nTO UPDATE THE MENU ENTER '2'. \nTO LOGOUT ENTER '3'.\n")
    if reply=='1':
      VIEW_MENU()
    elif reply=='2':
      UPDATE_MENU()
    else:
      HOME()
def UPDATE_MENU():
  reply=input("TO VIEW FOOD MENU ENTER '0'. \nTO EDIT AN EXISTING FOOD ITEM FROM THE MENU ENTER '1'. \nTO REMOVE A FOOD ITEM ENTER '2'. \nTO ADD NEW ITEM TO THE MENU ENTER '3'. \nTO CHECK STOCK ENTER '4'. \nTO INTRODUCE A DISCOUNT ENTER '5'. \nTO RETURN TO THE PREVIOUS PAGE ENTER '6'. \nTO EXIT ENTER '7'.\n")
  while reply not in ['0','1','2','3','4','5','6','7']:
    reply=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING : \nTO VIEW FOOD MENU ENTER '0'. \nTO EDIT AN EXISTING FOOD ITEM FROM THE MENU ENTER '1'. \nTO REMOVE A FOOD ITEM ENTER '2'. \nTO ADD NEW ITEM TO THE MENU ENTER '3'. \nTO CHECK STOCK ENTER '4'. \nTO RETURN TO THE PREVIOUS PAGE ENTER '6'. \nTO EXIT ENTER '7'.\n")
  if reply=='0':
    VIEW_MENU()
  elif reply=='1':
    EDIT_MENU()
  elif reply=='2':
    REMOVE_FOOD()
  elif reply=='3':
    EXTEND_MENU()
  elif reply=='4':
    VIEW_STOCK()
  elif reply=='5':
    INTRODUCE_DISCOUNT()
  elif reply=='6':
    ADMIN_LOGIN()
  else:
    EXIT()
def EDIT_MENU():
  if len(food_menu)==0:
    print("\n\nTHERE ARE NO FOOD ITEMS IN THE MENU.")
    UPDATE_MENU()
  else:
    print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
    for id,name in food_menu.items():
      print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {} ".format(id,name[0],name[1],name,[2]))
    ID=input("PLEASE ENTER THE FOOD ID WHICH YOU WANT TO EDIT\n")
    if ID not in food_menu.keys():
      ID=input("INVALID FOOD ID ! PLEASE SELECT A PROPER FOOD ID FROM THE MENU\n")
    else:
      reply=input("IF YOU WANT TO CHANGE THE QUANTITY OF THE FOOD ENTER '1'. \nIF YOU WANT TO CHANGE THE PRICE OF THE FOOD ENTER '2'. \nIF YOU DON'T WANT TO CONTINUE ENTER '3' TO RETURN TO THE PREVIOUS PAGE. \nTO EXIT RETURN '4'.\n")
      while reply not in ['1','2','3','4']:
        reply=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING: \nIF YOU WANT TO CHANGE THE QUANTITY OF THE FOOD ENTER '1'. \nIF YOU WANT TO CHANGE THE PRICE OF THE FOOD ENTER '2'. \nIF YOU DON'T WANT TO CONTINUE ENTER '3' TO RETURN TO THE PREVIOUS PAGE. \nTO EXIT RETURN '4'.\n")
      if reply=='1':
        val1=input("PLEASE ENTER THE NEW FOOD QUANTITY\n")
        reply1=input("\n\nTO CONFIRM THE CHANGES ENTER '1'. \nTO OMIT THE CHANGES AND RETURN TO THE LOGIN PAGE ENTER '2'. \nTO EXIT ENTER '3'\n")
        while reply1 not in ['1','2','3']:
          reply1=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING : \nTO CONFIRM THE CHANGES ENTER '1'. \nTO OMIT THE CHANGES AND RETURN TO THE PREVIOUS PAGE ENTER '2'. \nTO EXIT ENTER '3'\n")
        if reply1=='1':
          food_menu[ID][1]=val1
          print("QUANTITY UPDATED SUCCESSFULLY.\n")
          print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
          for id,name in food_menu.items():
            print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {}".format(id,name[0],name[1],name,[2]))
          EXIT()
        elif reply1=='2':
          UPDATE_MENU()
        else:
          EXIT()
      elif reply=='2':
        val=input("PLEASE ENTER NEW PRICE FOR THE FOOD ITEM.\n")
        reply1=input("\n\nTO CONFIRM THE CHANGES ENTER '1'. \nTO OMIT THE CHANGES AND RETURN TO THE LOGIN PAGE ENTER '2'. \nTO EXIT ENTER '3'\n")
        while reply1 not in ['1','2','3']:
          reply1=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING : \nTO CONFIRM THE CHANGES ENTER '1'. \nTO OMIT THE CHANGES AND RETURN TO THE PREVIOUS PAGE ENTER '2'. \nTO EXIT ENTER '3'\n")
        if reply1=='1':
          food_menu[ID][2]=val
          print("PRICE UPDATED SUCCESSFULLY.\n")
          print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
          for id,name in food_menu.items():
            print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {} ".format(id,name[0],name[1],name,[2]))
          EXIT()
        elif reply1=='2':
          UPDATE_MENU()
        else:
          EXIT()
      elif reply=='3':
        UPDATE_MENU()
      else:
        EXIT()
def REMOVE_FOOD():
  if len(food_menu)==0:
    print("\n\nTHERE ARE NO FOOD ITEMS IN THE MENU.")
    UPDATE_MENU()
  else:
    print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
    for id,name in food_menu.items():
      print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {} ".format(id,name[0],name[1],name,[2]))
    ID=input("PLEASE ENTER THE FOOD ID OF THE FOOD ITEM WHICH YOU WANT TO REMOVE\n")
    if ID not in food_menu.keys():
      ID=input("INVALID FOOD ID ! PLEASE SELECT A PROPER FOOD ID FROM THE MENU\n")
    else:
      removed_item=food_menu.pop(ID)
      print("ITEM REMOVED SUCCESSFULLY.\n")
      print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
      for id,name in food_menu.items():
        print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {} ".format(id,name[0],name[1],name,[2]))
      reply1=input("\n\nTO RETURN TO THE LOGIN PAGE ENTER '1'. \nTO EXIT ENTER '2'\n")
      while reply1 not in ['1','2']:
        reply1=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING : \nTO RETURN TO THE PREVIOUS PAGE ENTER '1'. \nTO EXIT ENTER '2'\n")
      if reply1=='1':
        UPDATE_MENU()
      else:
        EXIT()
def VIEW_MENU():
  if len(food_menu)==0:
    print("\n\nTHERE ARE NO FOOD ITEMS IN THE MENU.")
  else:
    print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
    for id,name in food_menu.items():
      print("FOOD ID : {} AND FOOD NAME : {}, QUANTITY : {}, PRICE : {} ".format(id,name[0],name[1],name,[2]))
  UPDATE_MENU()

def EXTEND_MENU():
  global food_id
  while True:
    food_name=input("PLEASE ENTER FOOD NAME\n")
    food_quantity=input("PLEASE ENTER FOOD QUANTITY\n")
    food_price='INR.'+input("PLEASE ENTER FOOD PRICE\n")
    food_stock=input("PLEASE ENTER FOOD STOCK\n")
    food_list.append([food_name,food_quantity,food_price,food_stock])
    reply=input("TO STOP ADDING ENTER 'S' ELSE SKIP.\n")
    if reply=='s' or reply=='S':
        break
  for ele in food_list:
    if ele[0] not in food_menu.values():
      food_id+=1
      food_menu[food_id]=ele
    else:
      reply=input("THE FOOD IS ALREADY THERE. \nTO UPDATE THE MENU ENTER '1'. \nTO RETURN TO THE PREVIOUS PAGE ENTER '2'. \nTO EXIT ENTER '3'.\n")
      while reply not in['1','2','3']:
        reply=input("INVALID INPUT! PLEASE SELECT FROM THE FOLLOWING : \nTO UPDATE THE MENU ENTER '1'. \nTO RETURN TO THE PREVIOUS PAGE ENTER '2'. \nTO EXIT ENTER '3'.\n")
      if reply=='1':
        break
        UPDATE_MENU()
      elif reply=='2':
        break
        ADMIN()

  reply=input(" THE NEW FOOD SUCCESSFULLY ADDED. \nTO RETURN TO THE PREVIOUS PAGE ENTER '1'. \nTO EXIT ENTER '2'.\n")
  while reply not in ['1','2']:
    reply=input(" INVALID INPUT! CHOOSE FROM THE FOLLOWING : \nTO RETURN TO THE PREVIOUS PAGE ENTER '1'. \nTO EXIT ENTER '2'.\n")
  if reply=='1':
    UPDATE_MENU()
  
  else:
    EXIT()
def VIEW_STOCK():
  if len(food_menu)==0:
    print("\n\nTHERE ARE NO FOOD ITEMS IN THE MENU.")
  else:
    print("\t\t\t\t RESTAURANT FOOD MENU \n\n\n")
    for id,name in food_menu.items():
      print("FOOD ID : {} FOOD NAME : {}, QUANTITY : {}, PRICE : {}, STOCK : {} ".format(id,name[0],name[1],name,[2],name[3]))
  UPDATE_MENU()
def INTRODUCE_DISCOUNT():
  amt = int(input("ENTER SALE AMOUNT :\n "))
  while (amt<0):
    amt = int(input("INVALID AMOUNT! PLEASE ENTER A SALE AMOUNT GREATER THAN '0' :\n "))
  if amt<=500:
    disc = amt*0.0125
  elif amt<=1500:
    disc=amt*0.025
  elif amt<=2500:
    disc=0.050 * amt
  else:
    disc=0.075 * amt
  print("\nTOTAL DISCOUNT : \n",disc)
  UPDATE_MENU()

HOME()
# Out:
# WELCOME TO RESTAURANT APPLICATION.
#
#
#
# TO LOGIN AS AN ADMIN ENTER '1'.
# TO LOGIN AS A GUEST ENTER '2'.
# TO EXIT ENTER '3'.
# 3
#
#
#
# 			THANK YOU FOR VISITING.
